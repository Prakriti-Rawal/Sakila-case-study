# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('mysql+pymysql://root:password@localhost/sakila')

# %% [markdown]
# # Views from Sakila Database

# %%
v_actor_info = """
select * from actor_info;
"""

df_actor_info = pd.read_sql(v_actor_info, engine)
df_actor_info
# Out:
#      actor_id first_name last_name  total_films
# 0           1   PENELOPE   GUINESS           19
# 1          10  CHRISTIAN     GABLE           22
# 2          20    LUCILLE     TRACY           30
# 3          30     SANDRA      PECK           19
# 4          40     JOHNNY      CAGE           29
# ..        ...        ...       ...          ...
# 195        86       GREG   CHAPLIN           27
# 196       121       LIZA   BERGMAN           25
# 197        97        MEG     HAWKE           27
# 198        14     VIVIEN    BERGEN           30
# 199        61  CHRISTIAN    NEESON           25
#
# [200 rows x 4 columns]

# %%
v_customer_list = """
SELECT * FROM customer_list;
"""

df_customer_list = pd.read_sql(v_customer_list, engine)
df_customer_list
# Out:
#       ID                 name                             address zip_code  \
# 0    218           VERA MCCOY              1168 Najafabad Parkway    40301
# 1    441       MARIO CHEATHAM              1924 Shimonoseki Drive    52625
# 2     69            JUDY GRAY             1031 Daugavpils Parkway    59025
# 3    176         JUNE CARROLL               757 Rustenburg Avenue    89668
# 4    320       ANTHONY SCHWAB        1892 Nabereznyje Tšelny Lane    28396
# ..   ...                  ...                                 ...      ...
# 594  303  WILLIAM SATTERFIELD             687 Alessandria Parkway    57587
# 595  213      GINA WILLIAMSON                1001 Miyakonojo Lane    67924
# 596    7         MARIA MILLER  900 Santiago de Compostela Parkway    93896
# 597  553             MAX PITT             1917 Kumbakonam Parkway    11892
# 598  438       BARRY LOVELACE                  1836 Korla Parkway    55405
#
#             phone        city         country   notes  SID
# ...

# %%
v_film_list = """
SELECT * FROM film_list;
"""

df_film_list = pd.read_sql(v_film_list, engine)
df_film_list
# Out:
#       FID              title  \
# 0       1   ACADEMY DINOSAUR
# 1       2     ACE GOLDFINGER
# 2       3   ADAPTATION HOLES
# 3       4   AFFAIR PREJUDICE
# 4       5        AFRICAN EGG
# ..    ...                ...
# 995   996     YOUNG LANGUAGE
# 996   997         YOUTH KICK
# 997   998       ZHIVAGO CORE
# 998   999  ZOOLANDER FICTION
# 999  1000          ZORRO ARK
#
#                                            description     category  price  \
# 0    A Epic Drama of a Feminist And a Mad Scientist...  Documentary   0.99
# 1    A Astounding Epistle of a Database Administrat...       Horror   4.99
# 2    A Astounding Reflection of a Lumberjack And a ...  Documentary   2.99
# 3    A Fanciful Documentary of a Frisbee And a Lumb...       Horror   2.99
# 4    A Fast-Paced Documentary of a Pastry Chef And ...       Family   2.99
# ..                                                 ...          ...    ...
# 995  A Unbelieveable Yarn of a Boat And a Database ...  Documentary   0.99
# ...

# %%
v_sales_by_film_category = """
SELECT * FROM sales_by_film_category;
"""

df_sales_by_film_category = pd.read_sql(v_sales_by_film_category, engine)
df_sales_by_film_category
# Out:
#        category  total_sales
# 0        Sports      5314.21
# 1        Sci-Fi      4756.98
# 2     Animation      4656.30
# 3         Drama      4587.39
# 4        Comedy      4383.58
# 5        Action      4375.85
# 6           New      4351.62
# 7         Games      4281.33
# 8       Foreign      4270.67
# 9        Family      4226.07
# 10  Documentary      4217.52
# 11       Horror      3722.54
# 12     Children      3655.55
# 13     Classics      3639.59
# 14       Travel      3549.64
# 15        Music      3417.72

# %%
v_sales_by_store = """
SELECT * FROM sales_by_store;
"""

df_sales_by_store = pd.read_sql(v_sales_by_store, engine)
df_sales_by_store
# Out:
#                  store       manager  total_sales
# 0  Woodridge,Australia  Jon Stephens     33726.77
# 1    Lethbridge,Canada  Mike Hillyer     33679.79

# %%
v_staff_list = """
SELECT * FROM staff_list;
"""

df_staff_list = pd.read_sql(v_staff_list, engine)
df_staff_list
# Out:
#    ID          name               address zip code        phone        city  \
# 0   1  Mike Hillyer     23 Workhaven Lane           14033335568  Lethbridge
# 1   2  Jon Stephens  1411 Lillydale Drive            6172235589   Woodridge
#
#      country  SID
# 0     Canada    1
# 1  Australia    2
